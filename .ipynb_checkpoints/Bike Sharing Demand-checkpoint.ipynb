# %%
from sklearn.ensemble import RandomForestRegressor
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
pd.options.mode.chained_assignment=None

# %%
# %matplotlib inline  #不用打show()
# Out:
# UsageError: unrecognized arguments: #不用打show()

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
submit=pd.read_csv('sampleSubmission.csv')

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.info()  #查看有沒有空值
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
test.describe()
# Out:
#             season      holiday   workingday      weather         temp  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed
# count  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157
# std       8.782741    19.293391     8.250151
# min       0.000000    16.000000     0.000000
# 25%      16.665000    49.000000     7.001500
# 50%      25.000000    65.000000    11.001400
# ...

# %%
#去掉ouliers
train=train[np.abs(train["count"]-train["count"].mean())<=(3*train["count"].std())]
print(train.shape)
# Out:
# (10739, 12)

# %%
data=train.append(test)
data
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
data.reset_index(inplace=True)
data
# Out:
#        index             datetime  season  holiday  workingday  weather  \
# 0          0  2011-01-01 00:00:00       1        0           0        1
# 1          1  2011-01-01 01:00:00       1        0           0        1
# 2          2  2011-01-01 02:00:00       1        0           0        1
# 3          3  2011-01-01 03:00:00       1        0           0        1
# 4          4  2011-01-01 04:00:00       1        0           0        1
# ...      ...                  ...     ...      ...         ...      ...
# 17227   6488  2012-12-31 19:00:00       1        0           1        2
# 17228   6489  2012-12-31 20:00:00       1        0           1        2
# 17229   6490  2012-12-31 21:00:00       1        0           1        1
# 17230   6491  2012-12-31 22:00:00       1        0           1        1
# 17231   6492  2012-12-31 23:00:00       1        0           1        1
#
#         temp   atemp  humidity  windspeed  casual  registered  count
# ...

# %%
data.drop('index',inplace=True,axis=1)
data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 17227  2012-12-31 19:00:00       1        0           1        2  10.66
# 17228  2012-12-31 20:00:00       1        0           1        2  10.66
# 17229  2012-12-31 21:00:00       1        0           1        1  10.66
# 17230  2012-12-31 22:00:00       1        0           1        1  10.66
# 17231  2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
data['datetime'][0]
# Out:
# '2011-01-01 00:00:00'

# %%
data['date']=data.datetime.apply(lambda x :x.split()[0])

# %%
data['hour']=data.datetime.apply(lambda x :x.split()[1].split(":")[0]).astype('int')

# %%
data['year']=data.datetime.apply(lambda x :x.split()[0].split("-")[0])

# %%
data['weekday']=data.date.apply(lambda dateString:datetime.strptime(dateString,"%Y-%m-%d").weekday())

# %%
data['month']=data.date.apply(lambda dateString:datetime.strptime(dateString,"%Y-%m-%d").month)

# %%
data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count        date  hour  year  \
# 0        81        0.0     3.0        13.0   16.0  2011-01-01     0  2011
# 1        80        0.0     8.0        32.0   40.0  2011-01-01     1  2011
# 2        80        0.0     5.0        27.0   32.0  2011-01-01     2  2011
# 3        75        0.0     3.0        10.0   13.0  2011-01-01     3  2011
# 4        75        0.0     0.0         1.0    1.0  2011-01-01     4  2011
#
#    weekday  month
# 0        5      1
# 1        5      1
# ...

# %%
fig,axes=plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(24,20)
sns.distplot(data["temp"],ax=axes[0][0])     #distplot畫分佈圖
sns.distplot(data["atemp"],ax=axes[0][1])
sns.distplot(data["humidity"],ax=axes[1][0])
sns.distplot(data["windspeed"],ax=axes[1][1])

axes[0][0].set(xlabel='temp',title='distribution of temp')
axes[0][1].set(xlabel='atemp',title='distribution of atemp')
axes[1][0].set(xlabel='humidity',title='distribution of humidity')
axes[1][1].set(xlabel='windspeed',title='distribution of windspeed');
# Out:
# C:\Users\Tibame\anaconda3\envs\ting\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Tibame\anaconda3\envs\ting\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
dataWind0=data[data['windspeed']==0]
dataWindNot0=data[data['windspeed']!=0]
rfModel_wind=RandomForestRegressor(n_estimators=1000,random_state=42)
windColums=['season','weather','humidity','month','temp','year','atemp']

# %%
rfModel_wind.fit(dataWindNot0[windColums],dataWindNot0['windspeed'])
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
wind0Values=rfModel_wind.predict(X=dataWind0[windColums])
dataWind0.loc[:,'windspeed']=wind0Values
data=dataWindNot0.append(dataWind0)
data.reset_index(inplace=True)
data.drop('index',inplace=True,axis=1)

# %%
sns.distplot(data["windspeed"]);
# Out:
# C:\Users\Tibame\anaconda3\envs\ting\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dataTrain=data[pd.notnull(data['count'])].sort_values(by=['datetime'])  #腳踏車租借數量不是空的，並用時間排序
dataTest=data[~pd.notnull(data['count'])].sort_values(by=['datetime'])  #腳踏車租借數量是空的，並用時間排序
datetime=dataTest['datetime']
yLabels=dataTrain['count']   #每小時腳踏車被租出去數量
sns.distplot(yLabels);
# Out:
# C:\Users\Tibame\anaconda3\envs\ting\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
yLabelsLog=np.log(yLabels)

# %%
sns.distplot(yLabelsLog);
# Out:
# C:\Users\Tibame\anaconda3\envs\ting\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
dropFeatures=['casual','registered','count','datetime','date']
dataTrain=dataTrain.drop(dropFeatures,axis=1)
dataTest=dataTest.drop(dropFeatures,axis=1)

# %%
dataTrain.head()
# Out:
#        season  holiday  workingday  weather  temp   atemp  humidity  \
# 15068       1        0           0        1  9.84  14.395        81
# 15069       1        0           0        1  9.02  13.635        80
# 15070       1        0           0        1  9.02  13.635        80
# 15071       1        0           0        1  9.84  14.395        75
# 15072       1        0           0        1  9.84  14.395        75
#
#        windspeed  hour  year  weekday  month
# 15068   6.978599     0  2011        5      1
# 15069   6.723159     1  2011        5      1
# 15070   6.723159     2  2011        5      1
# 15071   6.695585     3  2011        5      1
# 15072   6.695585     4  2011        5      1

# %%
dataTest.head()
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 9442        1        0           1        1  10.66  11.365        56
# 16365       1        0           1        1  10.66  13.635        56
# 16366       1        0           1        1  10.66  13.635        56
# 9443        1        0           1        1  10.66  12.880        56
# 9444        1        0           1        1  10.66  12.880        56
#
#        windspeed  hour  year  weekday  month
# 9442   26.002700     0  2011        3      1
# 16365   8.793563     1  2011        3      1
# 16366   8.793563     2  2011        3      1
# 9443   11.001400     3  2011        3      1
# 9444   11.001400     4  2011        3      1

# %%
rfModel=RandomForestRegressor(n_estimators=1000,random_state=42)
rfModel.fit(dataTrain,yLabelsLog)
preds=rfModel.predict(X=dataTrain)

# %%
preds
# Out:
# array([2.98651299, 3.44377777, 3.21724798, ..., 5.17058036, 4.93327532,
#        4.54485271])

# %%
predsTest=rfModel.predict(X=dataTest)
submission=pd.DataFrame({
    "datetime":datetime,
    "count":[max(0,x) for x in np.exp(predsTest)]
})

# %%
submission.head()
# Out:
#                   datetime      count
# 9442   2011-01-20 00:00:00  10.741879
# 16365  2011-01-20 01:00:00   4.849942
# 16366  2011-01-20 02:00:00   2.918483
# 9443   2011-01-20 03:00:00   3.032553
# 9444   2011-01-20 04:00:00   2.577142

# %%
submission.to_csv('bike_predictions_RF.csv',index=False)
